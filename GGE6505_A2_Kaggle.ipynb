# %% [markdown]
# <a href="https://colab.research.google.com/github/AndreaReid/GGE6505/blob/main/GGE6505_A2_Kaggle.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # GGE6505 A2 - Kaggle API

# %% [markdown]
# Nadav Avni, Andrea Reid
#
# Jan 31, 2022

# %% [markdown]
# **Install and Authentication**

# %% [markdown]
# 1. Install Kaggle and upload kaggle.json file that was downloaded to the computer.

# %%
! pip install -q kaggle

from google.colab import files

files.upload()
# Out:
#      <input type="file" id="files-36697136-00b3-4125-8411-d4e707ffdb33" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-36697136-00b3-4125-8411-d4e707ffdb33">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kaggle.json to kaggle.json
# {'kaggle.json': b'{"username":"andreareid","key":"f819bdaf75b849883b805cf6ee59e78e"}'}

# %% [markdown]
# 2. Make .kaggle directory and move json file into it.

# %%
! mkdir ~/.kaggle

! cp kaggle.json ~/.kaggle/

# %% [markdown]
# 3. Change permissions of file.

# %%
! chmod 600 ~/.kaggle/kaggle.json

# %% [markdown]
# 5. Test to make sure everything is working.

# %%
! kaggle datasets list
# Out:
# Warning: Looks like you're using an outdated API Version, please consider updating (server 1.5.12 / client 1.5.4)
# ref                                                         title                                               size  lastUpdated          downloadCount
# ----------------------------------------------------------  -------------------------------------------------  -----  -------------------  -------------
# yamqwe/omicron-covid19-variant-daily-cases                  Omicron daily cases by country (COVID-19 variant)  432KB  2022-01-24 07:15:53           8485
# nkitgupta/jigsaw-regression-based-data                      Jigsaw Regression Based Data                         3GB  2022-01-10 06:29:59            485
# prasertk/netflix-subscription-price-in-different-countries  Netflix subscription fee in different countries      3KB  2022-01-15 07:06:09            839
# yasserh/song-popularity-dataset                             Song Popularity Dataset                            805KB  2022-01-07 13:18:43           1149
# vishalmane10/anime-dataset-2022                             Anime DataSet 2022                                   5MB  2022-01-16 13:56:16            474
# yasserh/wine-quality-dataset                                Wine Quality Dataset                                21KB  2022-01-15 19:15:11            805
# carlmcbrideellis/gdp-20152019-finland-norway-and-sweden     GDP 2015-2019: Finland, Norway, and Sweden          365B  2022-01-05 07:48:49            422
# iamsouravbanerjee/analytics-industry-salaries-2022-india    Data Professionals Salary - 2022                    56KB  2022-01-25 16:42:15            962
# yasserh/uber-fares-dataset                                  Uber Fares Dataset                                   7MB  2022-01-01 15:54:14            943
# dansbecker/melbourne-housing-snapshot                       Melbourne Housing Snapshot                         451KB  2018-06-05 12:52:24          79331
# fedesoriano/stellar-classification-dataset-sdss17           Stellar Classification Dataset - SDSS17              7MB  2022-01-15 17:11:30            252
# datasnaek/youtube-new                                       Trending YouTube Video Statistics                  201MB  2019-06-03 00:56:47         164186
# zynicide/wine-reviews                                       Wine Reviews                                        51MB  2017-11-27 17:08:04         153108
# residentmario/ramen-ratings                                 Ramen Ratings                                       40KB  2018-01-11 16:04:39          32148
# datasnaek/chess                                             Chess Game Dataset (Lichess)                         3MB  2017-09-04 03:09:09          27233
# jpmiller/publicassistance                                   US Public Food Assistance                          703KB  2020-08-21 16:51:18          15390
# rtatman/188-million-us-wildfires                            1.88 Million US Wildfires                          168MB  2020-05-12 21:03:49          18668
# nasa/kepler-exoplanet-search-results                        Kepler Exoplanet Search Results                      1MB  2017-10-10 18:26:59           9801
# residentmario/things-on-reddit                              Things on Reddit                                    16MB  2017-10-26 14:10:15           8039
# nolanbconaway/pitchfork-data                                18,393 Pitchfork Reviews                            33MB  2017-01-13 04:18:10           9926

# %% [markdown]
# # Download a known dataset

# %%
from kaggle.api.kaggle_api_extended import KaggleApi

# Kaggle API
api = KaggleApi()
api.authenticate()

api.dataset_download_files('humansintheloop/Semantic-segmentation-of-aerial-imagery/Semantic segmentation dataset')

# %% [markdown]
# Unzip downloaded file.

# %%
# !unzip 'Semantic-segmentation-of-aerial-imagery.zip'

# %% [markdown]
# Show the first JPG image as an example.

# %%
import matplotlib.pyplot as plt
from PIL import Image

# Open image with Image module from PIL
img = Image.open('Semantic segmentation dataset/Tile 1/images/image_part_001.jpg')

# Show Images
plt.figure(1, (3, 3))
plt.imshow(img)
plt.title('Kaggle Dataset Download')

plt.show()
